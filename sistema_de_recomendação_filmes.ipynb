# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaArauj/Projetos_aprendizado_de_maquina/blob/main/sistema_de_recomenda%C3%A7%C3%A3o_filmes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# Carregando o arquivo movies

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["FilmeId", "Título", "Generos"]
filmes = filmes.set_index("FilmeId")
filmes.head()
# Out:
#                                      Título  \
# FilmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              Generos
# FilmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %%
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['generos'].value_counts()
    for x_label, grp in _df_2.groupby('titulo')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Título')
_ = plt.ylabel('Gêneros')

# %%
_df_1.groupby('generos').size().plot(kind='barh', color=sns.palettes.mpl_palette('Blues'))
plt.xlabel('Frequência')
plt.ylabel('Gêneros')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_0.groupby('titulo').size().plot(kind='barh', color=sns.palettes.mpl_palette('Blues'))
plt.xlabel('Frequência')
plt.ylabel('Título')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Carregando o arquivo ratings

# %%
notas = pd.read_csv("ratings.csv")
notas.columns = ["UsuarioId", "FilmeId", "Nota", "Momento"]
filmes = pd.read_csv("ratings.csv")
notas.head()
notas.describe()
# Out:
#            UsuarioId        FilmeId           Nota       Momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
n_df_14['Momento'].plot(kind='line', figsize=(8, 4), title='Momento')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
_df_13['Nota'].plot(kind='line', figsize=(8, 4), title='Nota')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
_df_12['FilmeId'].plot(kind='line', figsize=(8, 4), title='FilmeId')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['FilmeId']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'FilmeId'}, axis=1)
              .sort_values('FilmeId', ascending=True))
  xs = counted['FilmeId']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_11.sort_values('FilmeId', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('FilmeId')
_ = plt.ylabel('count()')

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['FilmeId']
  ys = series['Momento']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_10.sort_values('FilmeId', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('FilmeId')
_ = plt.ylabel('Momento')

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['UsuarioId']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'UsuarioId'}, axis=1)
              .sort_values('UsuarioId', ascending=True))
  xs = counted['UsuarioId']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_9.sort_values('UsuarioId', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('UsuarioId')
_ = plt.ylabel('count()')

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['UsuarioId']
  ys = series['Momento']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_8.sort_values('UsuarioId', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('UsuarioId')
_ = plt.ylabel('Momento')

# %%
_df_7.plot(kind='scatter', x='Nota', y='Momento', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_6.plot(kind='scatter', x='FilmeId', y='Nota', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_4['Nota'].plot(kind='hist', bins=20, title='Nota')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_3['FilmeId'].plot(kind='hist', bins=20, title='FilmeId')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_5['Momento'].plot(kind='hist', bins=20, title='Momento')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Primeira tentativa de recomendação

# %%
total_de_votos = notas['FilmeId'].value_counts()
total_de_votos.head()
# Out:
# FilmeId
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# Name: count, dtype: int64

# %%
#filmes.loc[356]
filmes['total_de_votos'] = total_de_votos
filmes.head()
# Out:
#    userId  movieId  rating  timestamp  total_de_votos
# 0       1        1     4.0  964982703             NaN
# 1       1        3     4.0  964981247           215.0
# 2       1        6     4.0  964982224           110.0
# 3       1       47     5.0  964983815            52.0
# 4       1       50     5.0  964982931             7.0

# %%
filmes.sort_values('total_de_votos', ascending=False).head(10)
# Out:
#       userId  movieId  rating   timestamp  total_de_votos
# 356        4      919     5.0   945079521           329.0
# 318        4      260     5.0   945079259           317.0
# 296        3     7991     5.0  1306463684           307.0
# 593        6       62     4.0   845553660           279.0
# 2571      19     1625     4.0   965710871           278.0
# 260        2   131724     5.0  1445714851           251.0
# 480        4     3591     1.0   986935199           238.0
# 110        1     1793     4.0   964981404           237.0
# 589        6       50     1.0   845553381           224.0
# 527        5      247     5.0   847435337           220.0

# %%
notas_medias = notas.groupby('FilmeId').mean()["Nota"]
notas_medias.head(10)
# Out:
# FilmeId
# 1     3.920930
# 2     3.431818
# 3     3.259615
# 4     2.357143
# 5     3.071429
# 6     3.946078
# 7     3.185185
# 8     2.875000
# 9     3.125000
# 10    3.496212
# Name: Nota, dtype: float64

# %%
filmes['notas_medias'] = notas_medias
filmes.sort_values('notas_medias', ascending=False).head(10)
# Out:
#        userId  movieId  rating   timestamp  total_de_votos  notas_medias
# 93320     599     2126     3.0  1498525186             1.0           5.0
# 6192       42     3033     4.0   996212624             1.0           5.0
# 4788       29     1224     4.0  1307905945             1.0           5.0
# 67618     438      292     3.5  1105666223             1.0           5.0
# 99636     610     1274     5.0  1493846688             1.0           5.0
# 8580       58      368     4.0   847718937             1.0           5.0
# 6835       45     5349     5.0  1021412297             1.0           5.0
# 27751     187    27879     4.5  1161850368             1.0           5.0
# 33649     228      362     2.0  1363222608             1.0           5.0
# 6818       45     4896     4.0  1007483576             2.0           5.0

# %%
filmes.query("total_de_votos >= 200").sort_values('notas_medias', ascending=False).head(20)
# Out:
#       userId  movieId  rating   timestamp  total_de_votos  notas_medias
# 318        4      260     5.0   945079259           317.0      4.429022
# 2959      19     3745     4.0   965702776           218.0      4.272936
# 50         1     1023     5.0   964982681           204.0      4.237745
# 260        2   131724     5.0  1445714851           251.0      4.231076
# 527        5      247     5.0   847435337           220.0      4.225000
# 1196      10    63113     3.5  1455302183           211.0      4.215640
# 1198      10    64969     0.5  1455357607           200.0      4.207500
# 296        3     7991     5.0  1306463684           307.0      4.197068
# 2571      19     1625     4.0   965710871           278.0      4.192446
# 356        4      919     5.0   945079521           329.0      4.164134
# 593        6       62     4.0   845553660           279.0      4.161290
# 2858      19     3108     4.0   965705917           204.0      4.056373
# ...
